# %%
# turn on autoreload: makes it so that if I edit a module,
#   I don't have to restart the kernel to see those edits
#   reflected in this notebook
# N.B. I *don't* have to rerun the import statement to
#   see the changes.
# %load_ext autoreload
# %autoreload 2

# %%
# my personal set of tools
import tools
import matplotlib.pyplot as plt
from datetime import date
import pandas as pd
# Out:
# /Users/kennethratliff/Desktop/home_exercises/env/lib/python3.11/site-packages/numbers_parser/__init__.py:47: UserWarning: Numbers version 14.3 not tested with this version
#   _ = _check_installed_numbers_version()

# %% [markdown]
# # Display current-month stats

# %%
file = "home_exercises.numbers"

pushups_goal = 1000

tools.exercise_projection(file, exercise="pushups", goal_total=pushups_goal)
# Out:
# PUSHUPS FOR 12/2024 AS OF 24/12/2024
# ------------------------------------
# So far today: 72
# So far this month: 827
# To reach 1000 by 12/31:
#    As of this morning: 30.62 per day
#    As of now: 24.71 per day

# %%
tools.exercise_statistics(file, "pushups")
# Out:
# PUSHUPS FOR 12/2024 AS OF 24/12/2024
# ------------------------------------
# Total: 827
# Days done: 20 of 24
# Per set:
#    max: 22
#    mean: 11.99
#    median: 12.0
# Per day:
#    max: 84
#    mean: 41.35
#    median: 40.0
#    mean, inc: 34.46
#    median, inc: 37.0

# %%
plt.style.use('Solarize_Light2')

fig, ax = tools.stacked_bar_exercise_month(file, exercise="pushups")

plt.show()

# %%
tools.cumsum_exercise_plot(file, 'pushups', startmonth=(2024,11), endmonth=(2024,12))

plt.show()
